# %% [markdown]
# # Reconstruction parcimonieuse ou compressive sensing

# %% [markdown]
# ## I. Cadre général et première tentative.

# %% [markdown]
# Le but du TP est de montrer que des techniques d'optimisation pour le Machine Learning permettent de récupérer des signaux qui admettent dans une certaine base une représentation parcimonieuse, c'est à dire mettant en jeu un faible nombre de coefficients.
#
# On s'intéresse donc à la reconstruction d'un vecteur $x$ (ici une image codées en niveaux de gris) en utilisant les valeurs de combinaisons aléatoire de certains pixels. Les combinaisons sont représentées par une matrice $\Phi$.
#
# Une première approche consiste à résoudre le problème $$ \min_x \frac{1}{2} ||\Phi x-y||_2^2$$ pour retrouver l'image.
#
# **Question 1 :** Commenter et compléter le code constituant le reste de la section I.

# %%
#
# Installation des librairies
#
#Pkg.add("")
#
#

#
# Repertoire ou se trouve le fichier cameraman.tif
#
#cd("$(homedir())/")

#
# Chargement des librairies de traitement d'image
#
using Images, Colors, LinearAlgebra, FFTW


img1 = load("cameraman.tif");    #
img = convert(Array{Gray},img1);   #
A = float(convert(Array,img));   #

tmp = @view img1[:,:]
# Out:
# ┌ Warning: `convert(Array{Gray{Any}}, img)` will soon switch to returning an array with non-concrete element type, which adds flexibility but
# │ with great cost to performance. To maintain the current behavior, use `Gray{Any}.(img)` instead.
# └ @ ImageCore /Users/julienblanchon/.julia/packages/ImageCore/iXG0W/src/deprecations.jl:6
# ┌ Info: It is recommended that you fix this now to avoid breakage when a new version is released and this warning is removed.
# │ Tip: to see all deprecation warnings together with code locations, launch Julia with `--depwarn=yes` and rerun your code.
# └ @ ImageCore /Users/julienblanchon/.julia/packages/ImageCore/iXG0W/src/deprecations.jl:7
# 256×256 view(::Array{Gray{N0f8},2}, :, :) with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.624)  …  Gray{N0f8}(0.596)
#  Gray{N0f8}(0.627)  Gray{N0f8}(0.604)     Gray{N0f8}(0.6)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.624)     Gray{N0f8}(0.596)
#  Gray{N0f8}(0.627)  Gray{N0f8}(0.604)     Gray{N0f8}(0.6)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.6)       Gray{N0f8}(0.592)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.608)  …  Gray{N0f8}(0.6)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.6)       Gray{N0f8}(0.584)
#  Gray{N0f8}(0.624)  Gray{N0f8}(0.624)     Gray{N0f8}(0.576)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.608)     Gray{N0f8}(0.576)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.604)     Gray{N0f8}(0.6)
#  Gray{N0f8}(0.604)  Gray{N0f8}(0.616)  …  Gray{N0f8}(0.608)
#  Gray{N0f8}(0.596)  Gray{N0f8}(0.588)     Gray{N0f8}(0.58)
#  Gray{N0f8}(0.616)  Gray{N0f8}(0.6)       Gray{N0f8}(0.592)
#  ⋮                                     ⋱  ⋮
#  Gray{N0f8}(0.522)  Gray{N0f8}(0.482)     Gray{N0f8}(0.384)
#  Gray{N0f8}(0.561)  Gray{N0f8}(0.502)  …  Gray{N0f8}(0.467)
#  Gray{N0f8}(0.318)  Gray{N0f8}(0.416)     Gray{N0f8}(0.38)
#  Gray{N0f8}(0.416)  Gray{N0f8}(0.549)     Gray{N0f8}(0.533)
#  Gray{N0f8}(0.537)  Gray{N0f8}(0.478)     Gray{N0f8}(0.376)
#  Gray{N0f8}(0.569)  Gray{N0f8}(0.455)     Gray{N0f8}(0.376)
#  Gray{N0f8}(0.447)  Gray{N0f8}(0.482)  …  Gray{N0f8}(0.392)
#  Gray{N0f8}(0.384)  Gray{N0f8}(0.447)     Gray{N0f8}(0.416)
#  Gray{N0f8}(0.498)  Gray{N0f8}(0.455)     Gray{N0f8}(0.471)
#  Gray{N0f8}(0.447)  Gray{N0f8}(0.518)     Gray{N0f8}(0.447)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.494)     Gray{N0f8}(0.443)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.494)  …  Gray{N0f8}(0.443)

# %%
# Extraction d'une sous-image contrastée
k    = 30;
orig = 60;
Aloc = A[orig:orig+k-1,orig:orig+k-1];
x   = (Aloc[:]);
n   = length(x);
m   = 500; 
Phi = randn(m,n);

imhsv=colorview(Gray,float(Aloc));
tmp=@view imhsv[:,:]

#
# Fin Extraction
#
# Out:
# 30×30 view(::Array{Gray{Float32},2}, :, :) with eltype Gray{Float32}:
#  Gray{Float32}(0.705882)   …  Gray{Float32}(0.721569)
#  Gray{Float32}(0.698039)      Gray{Float32}(0.713726)
#  Gray{Float32}(0.701961)      Gray{Float32}(0.717647)
#  Gray{Float32}(0.701961)      Gray{Float32}(0.729412)
#  Gray{Float32}(0.705882)      Gray{Float32}(0.717647)
#  Gray{Float32}(0.698039)   …  Gray{Float32}(0.764706)
#  Gray{Float32}(0.709804)      Gray{Float32}(0.588235)
#  Gray{Float32}(0.701961)      Gray{Float32}(0.0705882)
#  Gray{Float32}(0.690196)      Gray{Float32}(0.0588235)
#  Gray{Float32}(0.709804)      Gray{Float32}(0.0627451)
#  Gray{Float32}(0.701961)   …  Gray{Float32}(0.0627451)
#  Gray{Float32}(0.713726)      Gray{Float32}(0.0588235)
#  Gray{Float32}(0.705882)      Gray{Float32}(0.054902)
#  ⋮                         ⋱
#  Gray{Float32}(0.513726)      Gray{Float32}(0.054902)
#  Gray{Float32}(0.0941176)     Gray{Float32}(0.0627451)
#  Gray{Float32}(0.0588235)  …  Gray{Float32}(0.0588235)
#  Gray{Float32}(0.0588235)     Gray{Float32}(0.0627451)
#  Gray{Float32}(0.0627451)     Gray{Float32}(0.054902)
#  Gray{Float32}(0.0666667)     Gray{Float32}(0.0627451)
#  Gray{Float32}(0.0588235)     Gray{Float32}(0.0588235)
#  Gray{Float32}(0.054902)   …  Gray{Float32}(0.0588235)
#  Gray{Float32}(0.0470588)     Gray{Float32}(0.0588235)
#  Gray{Float32}(0.0431373)     Gray{Float32}(0.054902)
#  Gray{Float32}(0.0431373)     Gray{Float32}(0.054902)
#  Gray{Float32}(0.0392157)     Gray{Float32}(0.0588235)

# %% [markdown]
# **Question 2 :** Résoudre le problème de moindres carrés $$\min_x || \Phi x -y ||_2,$$ et afficher le résultat (attention, l'image doit être en niveaux de gris). Que constate-t-on?

# %%
y = Phi * x; # Vecteur des "observations" de l'image
## A compléter
# |\phi * x - y|
#x_best = (transpose(Phi) * Phi) \ (transpose(Phi) * y) 
x_best = pinv(Phi) * y
x_best = (x_best .- minimum(x_best)) ./ (maximum(x_best) - minimum(x_best))
x_reconstruct = reshape(x_best, (k, k))

colorview(Gray, x_reconstruct)
## Fin à compléter
# Out:
# 30×30 reinterpret(Gray{Float64}, ::Array{Float64,2}):
#  Gray{Float64}(0.60709)   Gray{Float64}(0.771796)  …  Gray{Float64}(0.684763)
#  Gray{Float64}(0.550007)  Gray{Float64}(0.569977)     Gray{Float64}(0.409244)
#  Gray{Float64}(0.345987)  Gray{Float64}(0.523885)     Gray{Float64}(0.660303)
#  Gray{Float64}(0.585663)  Gray{Float64}(0.785629)     Gray{Float64}(0.705405)
#  Gray{Float64}(0.639365)  Gray{Float64}(0.715412)     Gray{Float64}(0.890534)
#  Gray{Float64}(0.804409)  Gray{Float64}(0.674723)  …  Gray{Float64}(0.510211)
#  Gray{Float64}(0.690322)  Gray{Float64}(0.619845)     Gray{Float64}(0.63479)
#  Gray{Float64}(0.452716)  Gray{Float64}(0.780726)     Gray{Float64}(0.365643)
#  Gray{Float64}(0.543789)  Gray{Float64}(0.480834)     Gray{Float64}(0.321749)
#  Gray{Float64}(0.47398)   Gray{Float64}(0.611898)     Gray{Float64}(0.367662)
#  Gray{Float64}(0.844823)  Gray{Float64}(0.727632)  …  Gray{Float64}(0.423576)
#  Gray{Float64}(0.51446)   Gray{Float64}(0.543994)     Gray{Float64}(0.301466)
#  Gray{Float64}(0.570741)  Gray{Float64}(0.868426)     Gray{Float64}(0.292258)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.54408)   Gray{Float64}(0.393006)     Gray{Float64}(0.472682)
#  Gray{Float64}(0.324935)  Gray{Float64}(0.332979)     Gray{Float64}(0.302202)
#  Gray{Float64}(0.296518)  Gray{Float64}(0.20587)   …  Gray{Float64}(0.288044)
#  Gray{Float64}(0.49167)   Gray{Float64}(0.505227)     Gray{Float64}(0.403863)
#  Gray{Float64}(0.374449)  Gray{Float64}(0.480054)     Gray{Float64}(0.241624)
#  Gray{Float64}(0.227413)  Gray{Float64}(0.439822)     Gray{Float64}(0.51518)
#  Gray{Float64}(0.504226)  Gray{Float64}(0.311238)     Gray{Float64}(0.578598)
#  Gray{Float64}(0.566295)  Gray{Float64}(0.499421)  …  Gray{Float64}(0.223983)
#  Gray{Float64}(0.508456)  Gray{Float64}(0.472782)     Gray{Float64}(0.585288)
#  Gray{Float64}(0.17241)   Gray{Float64}(0.323202)     Gray{Float64}(0.401286)
#  Gray{Float64}(0.193245)  Gray{Float64}(0.353168)     Gray{Float64}(0.602518)
#  Gray{Float64}(0.492922)  Gray{Float64}(0.403637)     Gray{Float64}(0.611367)

# %% [markdown]
# #### II. Compressive sensing

# %% [markdown]
# On désire utiliser à présent la transformation discrète en cosinus pour obtenir une représentaiton parcimonieuse d'une image. Cette transfomation bijective est obtenue avec la fonction `dct`, son inverse s'appelant `idct`.
#
# A partir de la fonction IDCT de Julia, on calcule la matrice  $\Theta = \Phi*\Psi$, avec $\Psi$ la matrice représentative de IDCT dans la base canonique.

# %%
Theta = zeros(m,n);
for ii = 1:n
    ii
    ek = zeros(1,n);
    ek[ii] = 1; #Vecteur ei de la base canonique
    psi = idct(ek)';
    Theta[:,ii] = Phi*psi;
end

# %% [markdown]
# ### II.1. Utilisation d'un algorithme de sous-gradient

# %% [markdown]
# **Qestion 3 :** Soit $\lambda > 0$ (ici $\lambda=100$). Expliquer l'intérêt de
#  calculer $x_{sg}= \Psi z$ où $z$ résout $$\min_z \frac{1}{2} ||\Phi  \cdot \Psi  \cdot z -y||_2^2+ \lambda ||z||_1.$$
#
# **Qestion 4 :** Justifier la convexité de la fonctionnelle et donner son sous-différentiel.
#
# **Qestion 5 :** Compléter ci-dessous le code de sous-gradient. Vous considèrerez les différents choix de pas $\alpha_i$ vus en cours, et trouverez des réglages permettant d'obtenir un bon rendu visuel. On pourra se rappeler du fait que la solution de norme minimale a une norme inférieure à dix.

# %%
z = zeros(k^2, 1);
i = 0;
lambda = 1e-2;
choix_pas = 3; # 1 cas a, 2 cas b, 3 cas c
while i <= 1000
    i = i + 1
    ## A compléter
    # Calcul du sous gradients
    grad_k = 0.5 * transpose(Theta) * (Theta * z - y) + lambda * sign.(z)
    
    if choix_pas == 1
        z -= 1e-5 * grad_k #Constant
    elseif choix_pas == 2
        z -= 1 / (100*i) * grad_k #S1 diverge et S2 converge
    elseif choix_pas == 3
        z -= 1 / (1000*sqrt(i)) * grad_k #S1 diverge et S2 diverge
    end
    ## fin à compléter
end
norm(Theta \ y)
# Out:
# 8.796921223843954

# %%
z_reshape = reshape(z, (k, k))

colorview(Gray, z_reshape)
# Out:
# 30×30 reinterpret(Gray{Float64}, ::Array{Float64,2}):
#  Gray{Float64}(4.54894)      …  Gray{Float64}(-0.0720233)
#  Gray{Float64}(0.854424)        Gray{Float64}(0.0291763)
#  Gray{Float64}(0.687616)        Gray{Float64}(-0.0280012)
#  Gray{Float64}(0.545206)        Gray{Float64}(0.507009)
#  Gray{Float64}(0.304649)        Gray{Float64}(-0.106181)
#  Gray{Float64}(0.201295)     …  Gray{Float64}(0.223991)
#  Gray{Float64}(0.225591)        Gray{Float64}(-0.0893414)
#  Gray{Float64}(-0.360215)       Gray{Float64}(0.273628)
#  Gray{Float64}(0.207623)        Gray{Float64}(-0.236575)
#  Gray{Float64}(0.20526)         Gray{Float64}(0.335507)
#  Gray{Float64}(-0.0104)      …  Gray{Float64}(-0.0289569)
#  Gray{Float64}(0.217212)        Gray{Float64}(0.0229412)
#  Gray{Float64}(-0.248511)       Gray{Float64}(-0.186327)
#  ⋮                           ⋱
#  Gray{Float64}(-0.338087)       Gray{Float64}(0.104755)
#  Gray{Float64}(0.386672)        Gray{Float64}(-0.0031124)
#  Gray{Float64}(0.197734)     …  Gray{Float64}(-0.244364)
#  Gray{Float64}(0.241652)        Gray{Float64}(-0.037666)
#  Gray{Float64}(-0.0128797)      Gray{Float64}(-0.258869)
#  Gray{Float64}(0.0542185)       Gray{Float64}(-0.134285)
#  Gray{Float64}(0.0499463)       Gray{Float64}(0.38759)
#  Gray{Float64}(-0.0889417)   …  Gray{Float64}(0.0487108)
#  Gray{Float64}(-0.103635)       Gray{Float64}(0.0990612)
#  Gray{Float64}(-0.143194)       Gray{Float64}(0.306311)
#  Gray{Float64}(-0.00315812)     Gray{Float64}(0.0190248)
#  Gray{Float64}(-0.0571054)      Gray{Float64}(-0.0106251)

# %% [markdown]
# **Question 6 :** Expliquer le code suivant et conclure sur l'utilisation du sous-gradient

# %%
function my_function(n,k,z)
    x2 = zeros(n,1);
    for ii = 1:n
        ii
        ek = zeros(1,n);
        ek[ii] = 1;
        psi = idct(ek)';
        x2 = x2+psi*z[ii];
    end
    x2 = reshape(x2,(k,k));
    x2 = 1/(maximum(x2).-minimum(x2))*(x2.-minimum(x2));
    return x2
end
#
x2 = my_function(n,k,z);
imhsv = colorview(Gray, float(x2));
tmp=@view imhsv[:,:]
# Out:
# 30×30 view(reinterpret(Gray{Float64}, ::Array{Float64,2}), :, :) with eltype Gray{Float64}:
#  Gray{Float64}(0.605185)  Gray{Float64}(0.772293)  …  Gray{Float64}(0.688157)
#  Gray{Float64}(0.547316)  Gray{Float64}(0.570644)     Gray{Float64}(0.412082)
#  Gray{Float64}(0.342254)  Gray{Float64}(0.52367)      Gray{Float64}(0.659928)
#  Gray{Float64}(0.583192)  Gray{Float64}(0.785967)     Gray{Float64}(0.701801)
#  Gray{Float64}(0.635207)  Gray{Float64}(0.713886)     Gray{Float64}(0.88901)
#  Gray{Float64}(0.807094)  Gray{Float64}(0.675948)  …  Gray{Float64}(0.509343)
#  Gray{Float64}(0.6904)    Gray{Float64}(0.621443)     Gray{Float64}(0.633542)
#  Gray{Float64}(0.449153)  Gray{Float64}(0.777393)     Gray{Float64}(0.362498)
#  Gray{Float64}(0.54756)   Gray{Float64}(0.478501)     Gray{Float64}(0.323806)
#  Gray{Float64}(0.474403)  Gray{Float64}(0.605155)     Gray{Float64}(0.366468)
#  Gray{Float64}(0.838867)  Gray{Float64}(0.727752)  …  Gray{Float64}(0.423856)
#  Gray{Float64}(0.514485)  Gray{Float64}(0.544243)     Gray{Float64}(0.303553)
#  Gray{Float64}(0.571441)  Gray{Float64}(0.868134)     Gray{Float64}(0.29352)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.542795)  Gray{Float64}(0.392653)     Gray{Float64}(0.470256)
#  Gray{Float64}(0.321611)  Gray{Float64}(0.33551)      Gray{Float64}(0.299374)
#  Gray{Float64}(0.296075)  Gray{Float64}(0.20534)   …  Gray{Float64}(0.288783)
#  Gray{Float64}(0.488751)  Gray{Float64}(0.505182)     Gray{Float64}(0.40477)
#  Gray{Float64}(0.37363)   Gray{Float64}(0.480806)     Gray{Float64}(0.241869)
#  Gray{Float64}(0.22452)   Gray{Float64}(0.439177)     Gray{Float64}(0.516317)
#  Gray{Float64}(0.50393)   Gray{Float64}(0.309949)     Gray{Float64}(0.583815)
#  Gray{Float64}(0.563031)  Gray{Float64}(0.502858)  …  Gray{Float64}(0.222227)
#  Gray{Float64}(0.507869)  Gray{Float64}(0.474385)     Gray{Float64}(0.588074)
#  Gray{Float64}(0.178271)  Gray{Float64}(0.320488)     Gray{Float64}(0.399705)
#  Gray{Float64}(0.193684)  Gray{Float64}(0.355062)     Gray{Float64}(0.600221)
#  Gray{Float64}(0.49031)   Gray{Float64}(0.401306)     Gray{Float64}(0.608142)

# %% [markdown]
# # II.2. Utilisation d'un algorithme de sous-gradient projeté

# %% [markdown]
# **Question 7 :**  Expliquer l'intérêt de
#  calculer $x_{sgp}= \Psi z$ où $z$ résout $$\min_{\Phi  \cdot \Psi  \cdot z =y}  ||z||_1.$$

# %% [markdown]
# **Question 8 :** Rappeler la formule de la projection sur le convexe $\{x, \Phi  \cdot \Psi  \cdot z =y \}$ vue en cours.

# %% [markdown]
# **Question 9 :** Résoudre ce problème par l'algorithme de sous-gradient projeté et finaliser le calcul de la solution.

# %%
z = zeros(k^2, 1);
i = 3;
choix_pas = 1; # 1 cas a, 2 cas b, 3 cas c

##Initialisation (possible)
## A compléter
pinvTheta = pinv(Theta)
function projection(z)
    return z - pinvTheta * (Theta * z - y)
end
## Fin à compléter

while i <= 1000
    i = i + 1
    ## A compléter
    grad_k = sign.(z)
    if choix_pas == 1
        z -= 1e-5 * grad_k #Constant
    elseif choix_pas == 2
        z -= 1 / (100*i) * grad_k #S1 diverge et S2 converge
    elseif choix_pas == 3
        z -= 1 / (1000*sqrt(i)) * grad_k #S1 diverge et S2 diverge
    end
    z = projection(z)
    ## Fin à compléter
end

# %%
x3 = my_function(n,k,z);
imhsv = colorview(Gray,float(x3));
tmp =@view imhsv[:,:]
# Out:
# 30×30 view(reinterpret(Gray{Float64}, ::Array{Float64,2}), :, :) with eltype Gray{Float64}:
#  Gray{Float64}(0.608826)  Gray{Float64}(0.769477)  …  Gray{Float64}(0.685958)
#  Gray{Float64}(0.554422)  Gray{Float64}(0.569064)     Gray{Float64}(0.412943)
#  Gray{Float64}(0.347189)  Gray{Float64}(0.525719)     Gray{Float64}(0.66012)
#  Gray{Float64}(0.588361)  Gray{Float64}(0.786508)     Gray{Float64}(0.705194)
#  Gray{Float64}(0.641505)  Gray{Float64}(0.71794)      Gray{Float64}(0.890496)
#  Gray{Float64}(0.797993)  Gray{Float64}(0.671105)  …  Gray{Float64}(0.510779)
#  Gray{Float64}(0.688409)  Gray{Float64}(0.620968)     Gray{Float64}(0.634114)
#  Gray{Float64}(0.457121)  Gray{Float64}(0.77496)      Gray{Float64}(0.364374)
#  Gray{Float64}(0.542763)  Gray{Float64}(0.483528)     Gray{Float64}(0.319658)
#  Gray{Float64}(0.476319)  Gray{Float64}(0.610759)     Gray{Float64}(0.366071)
#  Gray{Float64}(0.842868)  Gray{Float64}(0.727375)  …  Gray{Float64}(0.421325)
#  Gray{Float64}(0.520799)  Gray{Float64}(0.54321)      Gray{Float64}(0.302892)
#  Gray{Float64}(0.572234)  Gray{Float64}(0.866735)     Gray{Float64}(0.287816)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.547809)  Gray{Float64}(0.386734)     Gray{Float64}(0.469255)
#  Gray{Float64}(0.322828)  Gray{Float64}(0.33449)      Gray{Float64}(0.296667)
#  Gray{Float64}(0.298018)  Gray{Float64}(0.200929)  …  Gray{Float64}(0.28647)
#  Gray{Float64}(0.491459)  Gray{Float64}(0.503667)     Gray{Float64}(0.399957)
#  Gray{Float64}(0.374686)  Gray{Float64}(0.479251)     Gray{Float64}(0.239635)
#  Gray{Float64}(0.228928)  Gray{Float64}(0.43604)      Gray{Float64}(0.513108)
#  Gray{Float64}(0.503664)  Gray{Float64}(0.314424)     Gray{Float64}(0.575436)
#  Gray{Float64}(0.563877)  Gray{Float64}(0.496858)  …  Gray{Float64}(0.225442)
#  Gray{Float64}(0.507565)  Gray{Float64}(0.467841)     Gray{Float64}(0.580269)
#  Gray{Float64}(0.168683)  Gray{Float64}(0.322136)     Gray{Float64}(0.404602)
#  Gray{Float64}(0.193237)  Gray{Float64}(0.350566)     Gray{Float64}(0.603705)
#  Gray{Float64}(0.490325)  Gray{Float64}(0.401676)     Gray{Float64}(0.61022)
