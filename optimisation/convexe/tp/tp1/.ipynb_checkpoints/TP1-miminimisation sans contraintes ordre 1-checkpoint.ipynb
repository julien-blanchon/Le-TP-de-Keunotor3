# %% [markdown]
# # Imports sous Notebook Python
# Dans ce TP, vous allez essentiellement programmer des classes dans un fichier que vous pourrez garder pour plus tard. Ces classes seront enregistrées dans des fichiers `Optim.py`  et `functions.py`. Cependant, le comportement par défaut d'un Notebook quand on demande d'importer un fichier est de ne pas le relire !!! Ainsi vos modifications dans les fichiers ne seront pas prises en compte. Pour que ce soit le cas, il faut lancer les commandes suivantes :

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import Optim as opt
import functions as func

# %% [markdown]
# ## Fonctionnement des classes et des fichiers de librairie sous python
# Dans cette section, nous allons nous chauffer un peu et apprendre (si on ne le sait pas déjà) comment fonctionnent les classes et les fichiers sous python. Le fichier `Optim.py` est vide mais le fichier `functions.py` contient déjà une classe nommée `square`. Ouvrez le fichier `function.py`. Cette classe `square` a 4 sous-fonctions, la fonction `__init__` se lance à l'appel de la classe (instanciation) et les autres fonctions se lancent avec les commandes suivantes

# %%
import functions as func
print("***** INSTANCIATION")
J=func.square()
print("***** AUTRES FONCTIONS")
a=np.array([1,2])
print(J.eval(a))
print(J.grad(a))
print(J.Hess(a))
print("***** ERREUR")
a=np.array([1,2,3])
print(J.eval(a))
# Out:
# ***** INSTANCIATION
# ***** AUTRES FONCTIONS
# 14.5
# [ 1 14]
# [[1. 0.]
#  [0. 7.]]
# ***** ERREUR
# Erreur de taille de x, on a  3  au lieu de  2
# 14.5

# %% [markdown]
# Sur le même modèle que précédemment, votre fonction doit vous rendre une erreur si on essaie de calculer un gradient ou une Hessienne en un point `a` qui n'est pas de taille `2`

# %%
import functions as func
J=func.square()
a=np.array([1,2,3])
print(J.grad(a))
print(J.Hess(a))
# Out:
# [ 1 14]
# [[1. 0.]
#  [0. 7.]]

# %% [markdown]
# ## Fonctions d'affichage
# On va se servir des fonctions d'affichage de matplotlib, qui sont `contour` ou `surf`. Essayez de comprendre les fonctions ci-dessous.

# %%
x = np.linspace(-1.0, 1.0, 100)
y = np.linspace(-1.0, 1.0, 100)
X, Y = np.meshgrid(x, y)
Z = 0.5*X**2+7*0.5*Y**2
levels=np.linspace(0.01,2,15)**2
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z,levels)
#ax.clabel(CS, inline=1, fontsize=10)
ax.set_title('Ligne de niveaux')
# Out:
# Text(0.5, 1.0, 'Ligne de niveaux')

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

fig = plt.figure()
ax = fig.gca(projection='3d')

x = np.linspace(-1.0, 1.0, 20)
y = np.linspace(-1.0, 1.0, 20)
X, Y = np.meshgrid(x, y)
Z = 0.5*X**2+7*0.5*Y**2
# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# %% [markdown]
# # Implémentation de nouvelles fonctions
# Dans le fichier `functions.py`, créez une classe nommée `Rosen()` sur le modèle de `square()` qui calcule la fonction, le gradient ou la Hessienne de :
# $$ f:(x,y)\mapsto 100*(y-x^2)^2 +(1-x)^2$$
# Créez aussi une fonction `oscill()` qui calcule la fonction, le gradient ou la Hessienne de :
# $$ g:(x,y)\mapsto \frac 1 2 x^2 +x\cos(y)$$

# %%
import functions as func
R=func.Rosen()
O=func.oscill()
a=np.array([1.3,2.45])
print(R.eval(a)) # 57.85
print(O.eval(a)) # -0.15630063026149965
print(R.grad(a))
print(R.Hess(a))
print(O.grad(a))
print(O.Hess(a))
# Out:
# 57.85
# [-0.15630063  1.11418343]
# [-394.6  152. ]
# [[1050. -520.]
#  [-520.  200.]]
# [ 0.52976875 -0.82909411]
# [[ 1.         -0.6377647 ]
#  [-0.6377647   1.00130063]]

# %% [markdown]
# # Tests de dérivées numériques
# Volontairement, je ne vous ai pas donné les réponses pour le gradient et la Hessienne. Avant de continuer, il faut vérifier que vos calculs sont bons. Pour cela on va faire des tests avec le gradient et la dérivée numérique. Pour ce faire on va partir d'un point $a$ quelconque et on prend une direction $d$ aléatoire. On compare ensuite pour plusieurs valeurs de $\varepsilon$ entre 1.e-8 et 1.e-1 les valeurs suivantes :
# $$\frac{J(a+\varepsilon d) -J(a)}{\varepsilon} \simeq (\nabla J(a),d)$$
# $$\frac{\nabla J(a+\varepsilon d) -\nabla J(a))}{\varepsilon} \simeq HJ(a)d$$
# On rappelle que quand on compare deux nombres $b$ et $c$, on s'intéresse au nombre $b/c$. Quand on compare deux vecteurs $b$ et $c$, on s'intéresse au ratio des normes et à l'angle donné par
# $$\frac{(b,c)}{\Vert b \Vert \Vert c\Vert}$$
# Créez une fonction `deriv_num(J,a,d,compute_grad=True,compute_Hess=True)` dans `Optim.py` qui teste la dérivée numérique d'une fonction `J`. Les arguments `compute_grad` et `compute_Hess` sont optionnels et déterminent si on doit vérifier le calcul de `J` pour son gradient et sa Hessienne. Ensuite testez votre code pour les 3 fonctions.

# %%
import functions as func
import Optim as opt
np.random.seed(42)
a=np.random.randn(2)
d=np.random.randn(2)
opt.deriv_num(func.oscill(),a,d)
# Out:
# 	eps 1.000e-01
# 	 Err Grad :[0.02834667 0.32574803]
# 	 Err Hess :0.01615794265520465
# 	 Angle Hess :0.010291566264646446
# 	eps 1.000e-02
# 	 Err Grad :[0.00218013 0.20385393]
# 	 Err Hess :0.002373664537075326
# 	 Angle Hess :0.00010131918666644868
# 	eps 1.000e-03
# 	 Err Grad :[0.00021141 0.19020244]
# 	 Err Hess :0.00024497966991776643
# 	 Angle Hess :1.010047946281567e-06
# 	eps 1.000e-04
# 	 Err Grad :[2.10744932e-05 1.88822770e-01]
# 	 Err Hess :2.457405286249159e-05
# 	 Angle Hess :1.0097186420310322e-08
# 	eps 1.000e-05
# 	 Err Grad :[2.10679147e-06 1.88684658e-01]
# 	 Err Hess :2.458163385732348e-06
# 	 Angle Hess :1.0096834479611516e-10
# 	eps 1.000e-06
# 	 Err Grad :[2.10750155e-07 1.88670845e-01]
# 	 Err Hess :2.458208587796662e-07
# 	 Angle Hess :1.0096368185941174e-12
# 	eps 1.000e-07
# 	 Err Grad :[2.12562661e-08 1.88669464e-01]
# 	 Err Hess :2.3657389491837932e-08
# 	 Angle Hess :1.0103029524088925e-14
# 	eps 1.000e-08
# 	 Err Grad :[1.18959752e-08 1.88669326e-01]
# 	 Err Hess :1.3415828448160028e-09
# 	 Angle Hess :0.0
# 	eps 1.000e-09
# 	 Err Grad :[8.46982375e-08 1.88669318e-01]
# 	 Err Hess :2.5691051508403007e-09
# 	 Angle Hess :0.0
# 	eps 1.000e-10
# 	 Err Grad :[6.04714397e-07 1.88669058e-01]
# 	 Err Hess :3.539217975356834e-07
# 	 Angle Hess :2.653433028854124e-14
# 	eps 1.000e-11
# 	 Err Grad :[1.47535024e-06 1.88665938e-01]
# 	 Err Hess :3.523843559838369e-06
# 	 Angle Hess :1.0650369475229127e-12
# 	eps 1.000e-12
# 	 Err Grad :[8.92497295e-06 1.88678939e-01]
# 	 Err Hess :3.5870155106643153e-05
# 	 Angle Hess :1.1654787135384481e-09

# %% [markdown]
# ## Méthode de gradient à pas fixe
# Nous allons implémenter une méthode de gradient à pas fixe, Il faut pour cela créer une dans optim.py fonction `fixed_step(J,x_0,step=1.,itermax=500,tol=1.e-5)` qui partira du point `x_0` qui appliquera des itérations de la méthode de gradient à pas fixe ('égal à `step`) pour minimiser `J` et qui s'arrêtera dès que la norme du gradient de `J` est plus petite que `tol` ou que le nombre d'itération maximal est atteint.
# Cette méthode nous rendra la liste des itérés `x` parcourus, la liste des valeurs de `J` lors des itérations et la liste des normes de gradient `J` correspondant.

# %%
x0=np.array([7,1.5])
x_list,cost_list,grad_list=opt.fixed_step(func.square(), x0, step=0.125)
plt.plot(cost_list)

# %% [markdown]
# Essayer avec plusieurs pas et affichez le nombre d'itérations nécessaires et la valeur finale de `J` obtenur, vous devez faire apparaître le fait qu'un pas trop petit ou trop grand ne fait pas converger

# %%
print(f"{'Fonction':<10}{'Step':<10}{'Norme Grad':^10}{'Iter':^10}")
print("\n")

#Square
x0=np.array([7,1.5])
for step in [0.4, 0.02, 0.01]:
    x_list, cost_list, grad_list = opt.fixed_step(func.square(), x0, step=step, itermax=1100)
    print(f"{'Square':<10}{step:<10}{grad_list[-1]:^10.2e}{len(x_list):^10}")
print("\n")

#oscill
x0=np.array([7,1.5])
for step in [2.5, 1, 0.04, 0.001]:
    x_list, cost_list, grad_list = opt.fixed_step(func.oscill(), x0, step=step, itermax=1100)
    print(f"{'Oscill':<10}{step:<10}{grad_list[-1]:^10.2e}{len(x_list):^10}")
print("\n")

#Rosen
x0=np.array([-1, 0])
for step in [0.02, 0.01, 0.0001]:
    x_list, cost_list, grad_list = opt.fixed_step(func.Rosen(), x0, step=step, itermax=1100)
    print(f"{'Rosen':<10}{step:<10}{grad_list[-1]:^10.2e}{len(x_list):^10}")
print("\n")
# Out:
# Fonction  Step      Norme Grad   Iter
#
#
# Square    0.4          inf       1101
# Square    0.02       9.84e-06    669
# Square    0.01       1.12e-04    1101
#
#
# Oscill    2.5          inf       1101
# Oscill    1          6.87e-07     9
# Oscill    0.04       9.72e-06    328
# Oscill    0.001      1.95e+00    1101
#
#
# Rosen     0.02         nan        9
# Rosen     0.01         nan        9
# Rosen     0.0001     2.20e+00    1101
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/functions.py:14: RuntimeWarning: overflow encountered in double_scalars
#   return 0.5*x[0]**2+7/2.*x[1]**2
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/functions.py:60: RuntimeWarning: overflow encountered in square
#   return (1/2)*x**2 + x*np.cos(x[1])
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/functions.py:36: RuntimeWarning: overflow encountered in double_scalars
#   return 100*(x[1]-x[0]**2)**2 + (1-x[0])**2
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/functions.py:39: RuntimeWarning: overflow encountered in double_scalars
#   return np.array([-400*x[0]*(x[1]-x[0]**2) - 2*(1-x[0]), 200*(x[1]-x[0]**2)])
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/Optim.py:35: RuntimeWarning: invalid value encountered in subtract
#   xk = xk - alphak*gradJk
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/functions.py:36: RuntimeWarning: invalid value encountered in double_scalars
#   return 100*(x[1]-x[0]**2)**2 + (1-x[0])**2
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/functions.py:39: RuntimeWarning: invalid value encountered in double_scalars
#   return np.array([-400*x[0]*(x[1]-x[0]**2) - 2*(1-x[0]), 200*(x[1]-x[0]**2)])

# %% [markdown]
# On aimerait maintenant visualiser l'évolution de l'algorithme. En utilisant la fonction `contour`, affichez sur un même graphique les points de `x_list` et la fonction `square`. Vous devez retrouver et imager les notions vues en cours.

# %%
x0 = np.array([7, 1.5])
f = func.square()
x_list, cost_list, grad_list = opt.fixed_step(func.square(), x0, step=0.2)
x = np.linspace(-1.0, 7.0, 100)
y = np.linspace(-1.0, 2.0, 100)
X, Y = np.meshgrid(x, y)
Z = f.eval((X,Y))
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z, levels=70)
ax.clabel(CS, inline=1, fontsize=10)
ax.axis('equal')
ax.set_title('Ligne de niveaux')
x_array = np.array(x_list)
plt.plot(x_array[:, 0], x_array[:, 1], '+r')

# %% [markdown]
# On aimerait maintenant visualiser l'évolution de l'algorithme. En utilisant la fonction `contour`, affichez sur un même graphique les points de `x_list` et la fonction `Rosen`. Vous devez retrouver et imager les notions vues en cours.

# %%
x0 = np.array([-1, 0])
f = func.Rosen()
x_list, cost_list, grad_list = opt.fixed_step(func.Rosen(), x0, step=2.e-3, itermax=1000)
x = np.linspace(-1.0, 1.0, 10)
y = np.linspace(-1.0, 1.0, 10)
X, Y = np.meshgrid(x, y)
Z = f.eval((X,Y))
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z, levels=70)
ax.clabel(CS, inline=1, fontsize=10)
ax.axis('equal')
ax.set_title('Ligne de niveaux')
x_array = np.array(x_list)
plt.plot(x_array[:, 0], x_array[:, 1], '-+r')

# %% [markdown]
# ## Algorithme de Wolfe
# Nous allons maintenant implémenter un algorithme de recherche linéaire de Wolfe, pour cela nous allons définir une fonction
# `Wolfe(J,x_0,e1=1.e-4,e2=0.99,itermax=500,itermax_W=20,tol=1.e-5)`
# Les nouveaux arguments sont `e1` et `e2`, les deux paramètres de Wolfe et `itermax_W`, le nombre maximal d'itérations à l'intérieur de l'algorithme de recherche de pas Wolfe. Si ce nombre d'itérations est atteint, on rend la borne inférieur du pas `smin`. Cette fonction doit rendre les variables `x_list,cost_list,grad_list` et aussi une variable `step_list` qui est la liste des pas utilisés

# %%
import functions as func
import Optim as opt
import numpy as np

x0 = np.array([4,1.5])
f = func.square()
x_list, cost_list, grad_list, step_list = opt.wolfe(f, x0, itermax=500)
x_list, cost_list, grad_list, step_list = opt.wolfe(func.oscill(), x0, itermax=500)
grad_list
# Out:
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/Optim.py:67: RuntimeWarning: invalid value encountered in add
#   phi_prime = lambda s: np.dot(J.grad(xk+s*dk), dk)
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/Optim.py:67: RuntimeWarning: invalid value encountered in multiply
#   phi_prime = lambda s: np.dot(J.grad(xk+s*dk), dk)
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/Optim.py:66: RuntimeWarning: invalid value encountered in add
#   phi = lambda s: J.eval(xk+s*dk) - gradJk
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/Optim.py:70: RuntimeWarning: invalid value encountered in less
#   small = not(phi(s) < e1*phi_prime(0)).any()
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/Optim.py:82: RuntimeWarning: invalid value encountered in less
#   small = not(phi(s) < e1*phi_prime(0)).any()
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/Optim.py:84: RuntimeWarning: invalid value encountered in add
#   xk = xk + s*dk
# [5.700073801087576,
#  0.6328383320768356,
#  0.4757943290731045,
#  0.2999129305956827,
#  0.07776168523017092,
#  0.003769408937010523,
#  7.983204451408316e-06]

# %% [markdown]
# Comparez l'algorithme de Wolfe et les algorithmes à pas fixe pour les autres fonctions à minimiser sur le modèle suivant

# %%
import functions as func
import Optim as opt
f=func.Rosen()
x0=np.array([-1,0])
x_list,cost_list,grad_list, step_list = opt.wolfe(f, x0, itermax=10000)
plt.loglog(grad_list)
plt.show()
x_array=np.array(x_list)
plt.plot(x_array[:,0],x_array[:,1],marker='+')
plt.show()
# Out:
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/functions.py:39: RuntimeWarning: invalid value encountered in double_scalars
#   return np.array([-400*x[0]*(x[1]-x[0]**2) - 2*(1-x[0]), 200*(x[1]-x[0]**2)])
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/functions.py:36: RuntimeWarning: invalid value encountered in double_scalars
#   return 100*(x[1]-x[0]**2)**2 + (1-x[0])**2

# %% [markdown]
# ## Etude du coût calcul
# Dans les problèmes d'optimisation actuels, le coût de calcul des gradients, des fonctions d'évaluation et des Hessiennes est ce qui limite le calcul d'optimisation. Nous voulons garder trace du nombre de fois où les fonctions `eval`, `grad` et `Hess` sont appelées. Pour cela, nous allons créer à l'initialisation des fonctions 3 compteurs `nb_eval`, `nb_grad` et `nb_Hess` qui seront implémentés dès qu'une des fonction correspondante est appellée. Nous aurons ainsi accès à la fin de l'optimisation à ces compteurs et au nombre d'appel. Implémentez ces compteurs pour les trois fonctions `square`, `Rosen` et `oscill` et comparez les coûts calculs des différents algorithmes d'optimisation. Attention, il est fort possible que vous puissiez gagner ici ou là quelques appels à ces fonctions, regardez bien votre code !!!
#
# Dans la pratique, le coût de calcul de `grad` est le même que celui de `eval` et pour calculer `grad(x)` il est le plus souvent nécessaire d'avoir calculé `eval(x)` juste avant.

# %%
x0 = np.array([-1, 0])
f = func.square()
x_list, cost_list, grad_list = opt.fixed_step(f, x0, step=2.e-3, itermax=1000)
x = np.linspace(-1.0, 1.0, 10)
y = np.linspace(-1.0, 1.0, 10)
X, Y = np.meshgrid(x, y)
Z = f.eval((X,Y))
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z, levels=70)
ax.clabel(CS, inline=1, fontsize=10)
ax.axis('equal')
ax.set_title('Ligne de niveaux')
x_array = np.array(x_list)
plt.plot(x_array[:, 0], x_array[:, 1], '-+r')
print(f.fcounter)
# Out:
# 1001

# %%
x0 = np.array([-1, 0])
f = func.square()
x_list, cost_list, grad_list, step_list = opt.wolfe(f, x0, itermax=1000)
x = np.linspace(-1.0, 1.0, 10)
y = np.linspace(-1.0, 1.0, 10)
X, Y = np.meshgrid(x, y)
Z = f.eval((X,Y))
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z, levels=70)
ax.clabel(CS, inline=1, fontsize=10)
ax.axis('equal')
ax.set_title('Ligne de niveaux')
x_array = np.array(x_list)
plt.plot(x_array[:, 0], x_array[:, 1], '-+r')
print(f.fcounter)
# Out:
# 5.0067901611328125e-06
# inf
# inf
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/functions.py:39: RuntimeWarning: invalid value encountered in double_scalars
#   return np.array([-400*x[0]*(x[1]-x[0]**2) - 2*(1-x[0]), 200*(x[1]-x[0]**2)])
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/functions.py:36: RuntimeWarning: invalid value encountered in double_scalars
#   return 100*(x[1]-x[0]**2)**2 + (1-x[0])**2
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/Optim.py:82: RuntimeWarning: invalid value encountered in less
#   small = not(phi(s) < e1*phi_prime(0)).any()
# /Users/julienblanchon/Git/julien-blanchon/Le-TP-de-Keunotor3/optimisation/tp/tp1/Optim.py:70: RuntimeWarning: invalid value encountered in less
#   small = not(phi(s) < e1*phi_prime(0)).any()
# 67

# %%
step_list
# Out:
# [5.0067901611328125e-06, inf, inf]

# %%
f.eval([3, 2])
# Out:
# 4904

# %%
f.fcounter
# Out:
# 1
